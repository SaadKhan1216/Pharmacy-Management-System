# %%
#Main Window
from PyQt5 import QtCore, QtGui, QtWidgets
from tkinter import *
import MySQLdb

class Ui_Form(object):
    def setupUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Pharmacy"))
        Form.setObjectName("Form")
        Form.resize(600, 485)
        icon = QtGui.QIcon()
        icon.addPixmap(QtGui.QPixmap("../../../../../../../../../../Desktop/pharmacy.jpg"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        Form.setWindowIcon(icon)
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(0, 0, 601, 91))
        font = QtGui.QFont()
        font.setPointSize(14)
        font.setBold(True)
        font.setWeight(75)
        self.label.setFont(font)
        self.label.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.label.setObjectName("label")
        self.mainwindow = QtWidgets.QFrame(Form)
        self.mainwindow.setGeometry(QtCore.QRect(0, 90, 601, 401))
        self.mainwindow.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));") 
        self.mainwindow.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.mainwindow.setFrameShadow(QtWidgets.QFrame.Raised)
        self.mainwindow.setObjectName("mainwindow")
        self.pushButton = QtWidgets.QPushButton(self.mainwindow)
        self.pushButton.setGeometry(QtCore.QRect(190, 70, 221, 91))
        self.pushButton.setStyleSheet("font: 75 9pt \"MS Shell Dlg 2\";")
        self.pushButton.setObjectName("pushButton")
        self.pushButton_2 = QtWidgets.QPushButton(self.mainwindow)
        self.pushButton_2.setGeometry(QtCore.QRect(190, 210, 221, 91))
        self.pushButton_2.setObjectName("pushButton_2")
        self.label.setText(_translate("Form", "                    PHARMACY MANAGEMENT SYSTEM"))
        self.pushButton.setText(_translate("Form", "MANAGEMENT"))
        self.pushButton_2.setText(_translate("Form", "EMPLOYEE"))
        self.pushButton.clicked.connect(self.login_mang)
        self.pushButton_2.clicked.connect(self.login_emp)
    def login_mang(self):
        a=login()
    def login_emp(self):
        b=Login()

        
class login:

    def __init__(self):
        self.window=Tk()
        self.window.title("login form")
        self.window.configure(background="deep sky blue")
        self.window.geometry("350x350")
        self.lab=Label(self.window,text="MANAGER LOGIN",bg="black",fg="white",bd=10,width=15,font=("arial",20)).place(x=30,y=10)
        self.lab1=Label(self.window,text="USER NAME",border=4,bg="black",fg="white").place(x=70,y=140)
        self.entry1=Entry(self.window,fg="black",bg="white")
        self.entry1.place(x=150,y=140)
        self.lab2=Label(self.window,text="PASSWORD",border=4,bg="black",fg="white").place(x=70,y=180)
        self.entry2=Entry(self.window,fg="black",bg="white")
        self.entry2.place(x=150,y=190)
        self.btn=Button(self.window,text="LOGIN",bg="black",fg="white",bd=9,width=10,command=self.buttonlog).place(x=80,y=220)
        self.window.mainloop()
    
    def buttonlog(self):
        a=self.entry1.get()
        b=self.entry2.get()
        if a=="admin" and b=="admin":
            self.managr()
        elif a!="admin" or b!="admin":
            self.error()

    def managr(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=Ui_wind_3()
        self.ui.setupUi(self.window)
        self.window.show() 
    def error(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=Ui_error()
        self.ui.setupUi(self.window)
        self.window.show()
        
class Login:

    def __init__(self):
        self.window=Tk()
        self.window.title("login form")
        self.window.configure(background="deep sky blue")
        self.window.geometry("350x350")
        self.lab=Label(self.window,text="EMPLOYEE LOGIN",bg="black",fg="white",bd=10,width=15,font=("arial",20)).place(x=30,y=10)
        self.lab1=Label(self.window,text="USER NAME",border=4,bg="black",fg="white").place(x=70,y=140)
        self.entry1=Entry(self.window,fg="black",bg="white")
        self.entry1.place(x=150,y=140)
        self.lab2=Label(self.window,text="PASSWORD",border=4,bg="black",fg="white").place(x=70,y=180)
        self.entry2=Entry(self.window,fg="black",bg="white")
        self.entry2.place(x=150,y=190)
        self.btn=Button(self.window,text="LOGIN",bg="black",fg="white",bd=9,width=10,command=self.buttonlog).place(x=80,y=220)
        self.window.mainloop()
    
    def buttonlog(self):
        a=self.entry1.get()
        b=self.entry2.get()
        if a=="hammad" and b=="hammad":
            self.emp()
        elif a!="hammad" or b!="hammad":
            self.error()
        
    def emp(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=Ui_wind_emp()
        self.ui.setupUi(self.window)
        self.window.show()
    def error(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=Ui_error()
        self.ui.setupUi(self.window)
        self.window.show()
        
class Ui_error(object):
    def setupUi(self, error):
        error.setObjectName("error")
        error.resize(199, 120)
        error.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.frame = QtWidgets.QFrame(error)
        self.frame.setGeometry(QtCore.QRect(0, 0, 211, 121))
        self.frame.setStyleSheet("background-color: rgb(240, 240, 240);")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(30, 30, 171, 20))
        self.label.setObjectName("label")
        
        _translate = QtCore.QCoreApplication.translate
        error.setWindowTitle(_translate("error", "error"))
        self.label.setText(_translate("error", "Incorrect username or password"))
      
        

        

        


        
class Ui_wind_3(object):
    def setupUi(self, wind_3):
        _translate = QtCore.QCoreApplication.translate
        wind_3.setWindowTitle(_translate("wind_3", "wind_3"))
        wind_3.setObjectName("wind_3")
        wind_3.resize(446, 397)
        wind_3.setStyleSheet("")
        self.frame = QtWidgets.QFrame(wind_3)
        self.frame.setGeometry(QtCore.QRect(0, 0, 451, 401))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(150, 120, 161, 51))
        self.pushButton.setObjectName("pushButton")
        self.pushButton_2 = QtWidgets.QPushButton(self.frame)
        self.pushButton_2.setGeometry(QtCore.QRect(150, 220, 161, 51))
        self.pushButton_2.setObjectName("pushButton_2")
        self.pushButton.setText(_translate("wind_3", "About Employee"))
        self.pushButton.clicked.connect(self.wind_5)
        self.pushButton_2.setText(_translate("wind_3", "Stock"))
        self.pushButton_2.clicked.connect(self.stock)
    def wind_5(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=Ui_Employee()
        self.ui.setupUi(self.window)
        self.window.show()
    def stock(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=Ui_Stock()
        self.ui.setupUi(self.window)
        self.window.show()
        
class Ui_wind_emp(object):
    def setupUi(self, wind_emp):
        _translate = QtCore.QCoreApplication.translate
        wind_emp.setWindowTitle(_translate("wind_emp", "wind_emp"))
        wind_emp.setObjectName("wind_emp")
        wind_emp.resize(472, 377)
        self.frame = QtWidgets.QFrame(wind_emp)
        self.frame.setGeometry(QtCore.QRect(0, 0, 471, 381))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(150, 100, 151, 51))
        self.pushButton.setObjectName("pushButton")
        self.pushButton_2 = QtWidgets.QPushButton(self.frame)
        self.pushButton_2.setGeometry(QtCore.QRect(150, 200, 151, 51))
        self.pushButton_2.setObjectName("pushButton_2")
        self.pushButton.setText(_translate("wind_emp", "About Customer"))
        self.pushButton.clicked.connect(self.aft_emp)
        self.pushButton_2.setText(_translate("wind_emp", "Take Order"))
        self.pushButton_2.clicked.connect(self.order)
    def aft_emp(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=Ui_aft_emp()
        self.ui.setupUi(self.window)
        self.window.show()
    def order(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=Ui_order()
        self.ui.setupUi(self.window)
        self.window.show()        


class Ui_aft_emp(object):
    def setupUi(self, aft_emp):
        _translate = QtCore.QCoreApplication.translate
        aft_emp.setWindowTitle(_translate("aft_emp", "aft_emp"))
        aft_emp.setObjectName("aft_emp")
        aft_emp.resize(586, 488)
        self.frame = QtWidgets.QFrame(aft_emp)
        self.frame.setGeometry(QtCore.QRect(0, 0, 591, 491))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(230, 120, 121, 41))
        self.pushButton.setObjectName("pushButton")
        self.pushButton_2 = QtWidgets.QPushButton(self.frame)
        self.pushButton_2.setGeometry(QtCore.QRect(230, 200, 121, 41))
        self.pushButton_2.setObjectName("pushButton_2")
        self.pushButton_3 = QtWidgets.QPushButton(self.frame)
        self.pushButton_3.setGeometry(QtCore.QRect(230, 280, 121, 41))
        self.pushButton_3.setObjectName("pushButton_3")
        self.pushButton_4 = QtWidgets.QPushButton(self.frame)
        self.pushButton_4.setGeometry(QtCore.QRect(230, 360, 121, 41))
        self.pushButton_4.setObjectName("pushButton_4")
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(210, 20, 161, 31))
        self.label.setStyleSheet("font: 75 14pt \"MS Shell Dlg 2\";")
        self.label.setObjectName("label")
        self.pushButton.setText(_translate("aft_emp", "ADD"))
        self.pushButton.clicked.connect(self.add)
        self.pushButton_2.setText(_translate("aft_emp", "UPDATE"))
        self.pushButton_2.clicked.connect(self.updt)
        self.pushButton_3.setText(_translate("aft_emp", "DELETE"))
        self.pushButton_3.clicked.connect(self.delt)
        self.pushButton_4.setText(_translate("aft_emp", "VIEW CUSTOMERS"))
        self.pushButton_4.clicked.connect(self.showcust)
        self.label.setText(_translate("aft_emp", "ABOUT CUSTOMER"))
    def add(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=Ui_customer()
        self.ui.setupUi(self.window)
        self.window.show()
    def delt(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=customer_delete()
        self.ui.setupUi(self.window)
        self.window.show()
    def updt(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=customer_update()
        self.ui.setupUi(self.window)
        self.window.show()
    def showcust(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=show_cust()
        self.ui.setupUi(self.window)
        self.window.show()

class Ui_customer(object):
    def setupUi(self, customer):
        _translate = QtCore.QCoreApplication.translate
        customer.setWindowTitle(_translate("customer", "customer"))
        customer.setObjectName("customer")
        customer.resize(590, 577)
        self.frame = QtWidgets.QFrame(customer)
        self.frame.setGeometry(QtCore.QRect(0, 0, 591, 581))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(170, 30, 221, 20))
        self.label.setStyleSheet("font: 75 14pt \"MS Shell Dlg 2\";")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(self.frame)
        self.label_2.setGeometry(QtCore.QRect(20, 100, 111, 21))
        self.label_2.setStyleSheet("font: 75 11pt \"MS Shell Dlg 2\";")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(self.frame)
        self.label_3.setGeometry(QtCore.QRect(20, 170, 131, 21))
        self.label_3.setStyleSheet("font: 75 11pt \"MS Shell Dlg 2\";")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(self.frame)
        self.label_4.setGeometry(QtCore.QRect(20, 243, 81, 20))
        self.label_4.setStyleSheet("font: 75 11pt \"MS Shell Dlg 2\";")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(self.frame)
        self.label_5.setGeometry(QtCore.QRect(20, 320, 111, 21))
        self.label_5.setStyleSheet("font: 75 11pt \"MS Shell Dlg 2\";")
        self.label_5.setObjectName("label_5")
        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(160, 450, 111, 41))
        self.pushButton.setObjectName("pushButton")
        self.frame_2 = QtWidgets.QFrame(self.frame)
        self.frame_2.setGeometry(QtCore.QRect(200, 100, 241, 21))
        self.frame_2.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(243, 243, 243, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame_2.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_2.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_2.setObjectName("frame_2")
        self.lineEdit = QtWidgets.QLineEdit(self.frame_2)
        self.lineEdit.setGeometry(QtCore.QRect(0, 0, 241, 20))
        self.lineEdit.setObjectName("lineEdit")

        self.frame_3 = QtWidgets.QFrame(self.frame)
        self.frame_3.setGeometry(QtCore.QRect(200, 170, 241, 21))
        self.frame_3.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_3.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_3.setObjectName("frame_3")
        self.lineEdit_2 = QtWidgets.QLineEdit(self.frame_3)
        self.lineEdit_2.setGeometry(QtCore.QRect(0, 0, 241, 20))
        self.lineEdit_2.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(243, 243, 243, 255), stop:1 rgba(255, 255, 255, 255));")
        self.lineEdit_2.setObjectName("lineEdit_2")
  
        self.frame_4 = QtWidgets.QFrame(self.frame)
        self.frame_4.setGeometry(QtCore.QRect(200, 240, 241, 21))
        self.frame_4.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_4.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_4.setObjectName("frame_4")
        self.lineEdit_3 = QtWidgets.QLineEdit(self.frame_4)
        self.lineEdit_3.setGeometry(QtCore.QRect(0, 0, 241, 20))
        self.lineEdit_3.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(243, 243, 243, 255), stop:1 rgba(255, 255, 255, 255));")
        self.lineEdit_3.setObjectName("lineEdit_3")
        self.frame_5 = QtWidgets.QFrame(self.frame)
        self.frame_5.setGeometry(QtCore.QRect(200, 320, 241, 21))
        self.frame_5.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_5.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_5.setObjectName("frame_5")
        self.lineEdit_4 = QtWidgets.QLineEdit(self.frame_5)
        self.lineEdit_4.setGeometry(QtCore.QRect(0, 0, 241, 20))
        self.lineEdit_4.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(243, 243, 243, 255), stop:1 rgba(255, 255, 255, 255));")
        self.lineEdit_4.setObjectName("lineEdit_4")
        self.label.setText(_translate("customer", "            ADD CUSTOMER"))
        self.label_2.setText(_translate("customer", "CUSTOMER ID"))
        self.label_3.setText(_translate("customer", "CUSTOMER NAME"))
        self.label_4.setText(_translate("customer", "MOBILE NO"))
        self.label_5.setText(_translate("customer", "ADDRESS"))
        self.pushButton.setText(_translate("customer", "ADD"))
        self.pushButton.clicked.connect(self.add_cust)
    def add_cust(self):
        db=MySQLdb.connect('localhost','root','test123','project')
        cursor=db.cursor()
        a=self.lineEdit.text()
        b=self.lineEdit_2.text()
        c=self.lineEdit_3.text()
        d=self.lineEdit_4.text()
        sql="""INSERT into customer(Customer_ID,Customer_Name,Mobile_NO,Address) values ('%s','%s','%s','%s')"""%(a,b,c,d)
        cursor.execute(sql)
        db.commit()
        db.close()
        self.lineEdit.clear()
        self.lineEdit_2.clear()
        self.lineEdit_3.clear()
        self.lineEdit_4.clear()
        

class customer_delete:
    def setupUi(self, Dialog):
        Dialog.setObjectName("Dialog")
        Dialog.resize(400, 265)
        self.frame = QtWidgets.QFrame(Dialog)
        self.frame.setGeometry(QtCore.QRect(0, 0, 591, 581))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.label = QtWidgets.QLabel(Dialog)
        self.label.setGeometry(QtCore.QRect(100, 20, 200, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.label.setFont(font)
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Dialog)
        self.label_2.setGeometry(QtCore.QRect(60, 110, 47, 13))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.label_2.setFont(font)
        self.label_2.setObjectName("label_2")
        self.lineEdit = QtWidgets.QLineEdit(Dialog)
        self.lineEdit.setGeometry(QtCore.QRect(130, 110, 141, 20))
        self.lineEdit.setObjectName("lineEdit")
        self.whcom = QtWidgets.QComboBox(Dialog)
        self.whcom.setGeometry(QtCore.QRect(130, 70, 141, 22))
        self.whcom.setObjectName("whcom")
        list1=['Customer_ID']
        for i in list1:
            self.whcom.addItem(i)
        self.dtlbut = QtWidgets.QPushButton(Dialog)
        self.dtlbut.setGeometry(QtCore.QRect(190, 200, 75, 23))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.dtlbut.setFont(font)
        self.dtlbut.setObjectName("dtlbut")
        self.dtlbut.clicked.connect(self.delete)
        self.retranslateUi(Dialog)
        QtCore.QMetaObject.connectSlotsByName(Dialog)

    def retranslateUi(self, Dialog):
        _translate = QtCore.QCoreApplication.translate
        Dialog.setWindowTitle(_translate("Dialog", "Dialog"))
        self.label.setText(_translate("Dialog", "DELETE CUSTOMER"))
        self.dtlbut.setText(_translate("Dialog", "DELETE"))
        
    def delete(self):
        db = MySQLdb.connect("localhost","root","test123","project")
        cursor = db.cursor()
        a=self.lineEdit.text() 
        b = self.whcom.currentText()
        sql="""delete from customer where %s='%s'"""%(b,a)
        b=self.lineEdit.text() 
        cursor.execute(sql)
        db.commit()
        db.close()
        self.lineEdit.clear()

                
class customer_update:
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(604, 298)
        self.frame = QtWidgets.QFrame(Form)
        self.frame.setGeometry(QtCore.QRect(0, 0, 591, 581))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.setcombx = QtWidgets.QComboBox(Form)
        self.setcombx.setGeometry(QtCore.QRect(40, 100, 131, 21))
        self.setcombx.setObjectName("setcombx")
        list=['Customer_Name','Mobile_No','Address']
        for i in list:
            self.setcombx.addItem(i)
        self.wherecom = QtWidgets.QComboBox(Form)
        self.wherecom.setGeometry(QtCore.QRect(390, 100, 141, 21))
        self.wherecom.setObjectName("wherecom")
        list1=['Customer_ID']
        for i in list1:
            self.wherecom.addItem(i)
        self.setlb = QtWidgets.QLabel(Form)
        self.setlb.setGeometry(QtCore.QRect(90, 80, 31, 16))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.setlb.setFont(font)
        self.setlb.setObjectName("setlb")
        self.wherelb = QtWidgets.QLabel(Form)
        self.wherelb.setGeometry(QtCore.QRect(440, 80, 47, 13))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.wherelb.setFont(font)
        self.wherelb.setObjectName("wherelb")
        self.uplb = QtWidgets.QLabel(Form)
        self.uplb.setGeometry(QtCore.QRect(220, 10, 161, 41))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.uplb.setFont(font)
        self.uplb.setObjectName("uplb")
        self.upbut = QtWidgets.QPushButton(Form)
        self.upbut.setGeometry(QtCore.QRect(150, 240, 75, 23))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.upbut.setFont(font)
        self.upbut.setObjectName("upbut")
        self.upbut.clicked.connect(self.update)
        self.seten = QtWidgets.QLineEdit(Form)
        self.seten.setGeometry(QtCore.QRect(40, 130, 131, 20))
        self.seten.setObjectName("seten")
        self.ehereen = QtWidgets.QLineEdit(Form)
        self.ehereen.setGeometry(QtCore.QRect(390, 130, 141, 20))
        self.ehereen.setObjectName("ehereen")
        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.setlb.setText(_translate("Form", "SET"))
        self.wherelb.setText(_translate("Form", "WHERE"))
        self.uplb.setText(_translate("Form", "UPDATE"))
        self.upbut.setText(_translate("Form", "UPDATE"))
        
    
    def update(self):
        db = MySQLdb.connect("localhost","root","test123","project")
        cursor = db.cursor()
        a= self.seten.text()
        c = self.setcombx.currentText()
        b= self.ehereen.text()
        d = self.wherecom.currentText()
        sql="""update customer set %s='%s' where %s='%s'"""%(c,a,d,b)
        cursor.execute(sql)
        db.commit()
        db.close()
        self.seten.clear()
        self.ehereen.clear()
        
class show_cust:
    def __init__(self):
        self.db = MySQLdb.connect("localhost","root","test123","project")
        self.crr = self.db.cursor()
        
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(500, 590)
        self.frame = QtWidgets.QFrame(Form)
        self.frame.setGeometry(QtCore.QRect(-1, -1, 881, 41))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.frame_2 = QtWidgets.QFrame(Form)
        self.frame_2.setGeometry(QtCore.QRect(-1, 40, 41, 561))
        self.frame_2.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame_2.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_2.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_2.setObjectName("frame_2")
        self.tableWidget = QtWidgets.QTableWidget(Form)
        self.tableWidget.setGeometry(QtCore.QRect(35, 40, 841, 551))
        self.tableWidget.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.tableWidget.setObjectName("tableWidget")
        self.tableWidget.setColumnCount(4)
        self.tableWidget.setRowCount(0)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(0, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(1, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(2, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(3, item)

       
        self.crr.execute('select * from customer')
        res = self.crr.fetchall()
        self.tableWidget.setRowCount(0)
        for row_number, row_data in enumerate(res):
            self.tableWidget.insertRow(row_number)
            for column_number, data in enumerate(row_data):
                self.tableWidget.setItem(row_number,column_number,QtWidgets.QTableWidgetItem(str(data)))

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        item = self.tableWidget.horizontalHeaderItem(0)
        item.setText(_translate("Form", "Customer_ID "))
        item = self.tableWidget.horizontalHeaderItem(1)
        item.setText(_translate("Form", "Customer_Name "))
        item = self.tableWidget.horizontalHeaderItem(2)
        item.setText(_translate("Form", "Mobile_No "))
        item = self.tableWidget.horizontalHeaderItem(3)
        item.setText(_translate("Form", "Address"))

       
class Ui_Employee(object):
    def setupUi(self, Employee):
        _translate = QtCore.QCoreApplication.translate
        Employee.setWindowTitle(_translate("Employee", "Employee"))
        Employee.setObjectName("Employee")
        Employee.resize(563, 512)
        self.frame = QtWidgets.QFrame(Employee)
        self.frame.setGeometry(QtCore.QRect(0, 0, 561, 511))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(220, 120, 141, 41))
        self.pushButton.setObjectName("pushButton")
        self.pushButton_2 = QtWidgets.QPushButton(self.frame)
        self.pushButton_2.setGeometry(QtCore.QRect(220, 200, 141, 41))
        self.pushButton_2.setObjectName("pushButton_2")
        self.pushButton_3 = QtWidgets.QPushButton(self.frame)
        self.pushButton_3.setGeometry(QtCore.QRect(220, 282, 141, 41))
        self.pushButton_3.setObjectName("pushButton_3")
        self.pushButton_4 = QtWidgets.QPushButton(self.frame)
        self.pushButton_4.setGeometry(QtCore.QRect(220, 360, 141, 41))
        self.pushButton_4.setObjectName("pushButton_4")
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(210, 20, 161, 31))
        self.label.setStyleSheet("font: 75 14pt \"MS Shell Dlg 2\";")
        self.label.setObjectName("label")
        self.pushButton.setText(_translate("Employee", "ADD"))
        self.pushButton.clicked.connect(self.add_emp)
        self.pushButton_2.setText(_translate("Employee", "UPDATE"))
        self.pushButton_2.clicked.connect(self.updt_emp)
        self.pushButton_3.setText(_translate("Employee", "DELETE"))
        self.pushButton_3.clicked.connect(self.delt_emp)
        self.pushButton_4.setText(_translate("Employee", "VIEW EMPLOYEES"))
        self.pushButton_4.clicked.connect(self.show_emp)
        self.label.setText(_translate("Employee", "ABOUT EMPLOYEE"))
    def add_emp(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=Ui_employee()
        self.ui.setupUi(self.window)
        self.window.show()
    def delt_emp(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=employee_delete()
        self.ui.setupUi(self.window)
        self.window.show()
    def updt_emp(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=employee_update()
        self.ui.setupUi(self.window)
        self.window.show()
    def show_emp(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=show_employee()
        self.ui.setupUi(self.window)
        self.window.show()
class Ui_employee(object):
    def setupUi(self, employee):
        _translate = QtCore.QCoreApplication.translate
        employee.setWindowTitle(_translate("employee", "employee"))
        employee.setObjectName("employee")
        employee.resize(585, 569)
        self.frame = QtWidgets.QFrame(employee)
        self.frame.setGeometry(QtCore.QRect(0, 0, 581, 571))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(210, 40, 151, 31))
        self.label.setStyleSheet("font: 75 14pt \"MS Shell Dlg 2\";")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(self.frame)
        self.label_2.setGeometry(QtCore.QRect(30, 110, 101, 21))
        self.label_2.setStyleSheet("font: 75 11pt \"MS Shell Dlg 2\";")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(self.frame)
        self.label_3.setGeometry(QtCore.QRect(30, 190, 121, 21))
        self.label_3.setStyleSheet("font: 75 11pt \"MS Shell Dlg 2\";")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(self.frame)
        self.label_4.setGeometry(QtCore.QRect(30, 260, 111, 21))
        self.label_4.setStyleSheet("font: 75 11pt \"MS Shell Dlg 2\";")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(self.frame)
        self.label_5.setGeometry(QtCore.QRect(30, 330, 101, 21))
        self.label_5.setStyleSheet("font: 75 11pt \"MS Shell Dlg 2\";")
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(self.frame)
        self.label_6.setGeometry(QtCore.QRect(30, 400, 101, 21))
        self.label_6.setStyleSheet("font: 75 11pt \"MS Shell Dlg 2\";")
        self.label_6.setObjectName("label_6")
        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(150, 480, 101, 31))
        self.pushButton.setObjectName("pushButton")
        self.frame_2 = QtWidgets.QFrame(self.frame)
        self.frame_2.setGeometry(QtCore.QRect(200, 110, 231, 21))
        self.frame_2.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(255, 255, 255, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame_2.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_2.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_2.setObjectName("frame_2")
        self.lineEdit = QtWidgets.QLineEdit(self.frame_2)
        self.lineEdit.setGeometry(QtCore.QRect(0, 0, 231, 20))
        self.lineEdit.setObjectName("lineEdit")
        self.frame_3 = QtWidgets.QFrame(self.frame)
        self.frame_3.setGeometry(QtCore.QRect(200, 190, 231, 21))
        self.frame_3.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(255, 255, 255, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame_3.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_3.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_3.setObjectName("frame_3")
        self.lineEdit_2 = QtWidgets.QLineEdit(self.frame_3)
        self.lineEdit_2.setGeometry(QtCore.QRect(0, 0, 231, 20))
        self.lineEdit_2.setObjectName("lineEdit_2")
        self.frame_4 = QtWidgets.QFrame(self.frame)
        self.frame_4.setGeometry(QtCore.QRect(200, 260, 231, 21))
        self.frame_4.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(255, 255, 255, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame_4.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_4.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_4.setObjectName("frame_4")
        self.lineEdit_3 = QtWidgets.QLineEdit(self.frame_4)
        self.lineEdit_3.setGeometry(QtCore.QRect(0, 0, 231, 20))
        self.lineEdit_3.setObjectName("lineEdit_3")
        self.frame_5 = QtWidgets.QFrame(self.frame)
        self.frame_5.setGeometry(QtCore.QRect(200, 330, 231, 21))
        self.frame_5.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(255, 255, 255, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame_5.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_5.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_5.setObjectName("frame_5")
        self.lineEdit_4 = QtWidgets.QLineEdit(self.frame_5)
        self.lineEdit_4.setGeometry(QtCore.QRect(0, 0, 231, 20))
        self.lineEdit_4.setObjectName("lineEdit_4")
        self.frame_6 = QtWidgets.QFrame(self.frame)
        self.frame_6.setGeometry(QtCore.QRect(200, 400, 231, 21))
        self.frame_6.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(255, 255, 255, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame_6.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_6.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_6.setObjectName("frame_6")
        self.lineEdit_5 = QtWidgets.QLineEdit(self.frame_6)
        self.lineEdit_5.setGeometry(QtCore.QRect(0, 0, 241, 20))
        self.lineEdit_5.setObjectName("lineEdit_5")
        self.label.setText(_translate("employee", "ADD EMPLOYEE"))
        self.label_2.setText(_translate("employee", "EMPLOYEE_ID"))
        self.label_3.setText(_translate("employee", "EMPLOYEE_NAME"))
        self.label_4.setText(_translate("employee", "MOBILE_PHONE"))
        self.label_5.setText(_translate("employee", "ADDRESS"))
        self.label_6.setText(_translate("employee", "INCOME"))
        self.pushButton.setText(_translate("employee", "ADD"))
        self.pushButton.clicked.connect(self.add)
        Employee_ID=self.label_2.text()
        Employee_Name=self.label_3.text()
        Mobile_Phone=self.label_4.text()
        Address=self.label_5.text()
        Income=self.label_6.text()
    
    def add(self):
        db=MySQLdb.connect('localhost','root','test123','project')
        cursor=db.cursor()
        a=self.lineEdit.text()
        b=self.lineEdit_2.text()
        c=self.lineEdit_3.text()
        d=self.lineEdit_4.text()
        e=self.lineEdit_5.text()
        sql="""INSERT into employee(Employee_ID,Employee_Name,Mobile_Phone,Address,Income) values ('%s','%s','%s','%s','%s')"""%(a,b,c,d,e)
        cursor.execute(sql)
        db.commit()
        db.close()
        self.lineEdit.clear()
        self.lineEdit_2.clear()
        self.lineEdit_3.clear()
        self.lineEdit_4.clear()
        self.lineEdit_5.clear()
        
class employee_delete:
    def setupUi(self, Dialog):
        Dialog.setObjectName("Dialog")
        Dialog.resize(400, 265)
        self.frame = QtWidgets.QFrame(Dialog)
        self.frame.setGeometry(QtCore.QRect(0, 0, 591, 581))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.label = QtWidgets.QLabel(Dialog)
        self.label.setGeometry(QtCore.QRect(100, 20, 200, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.label.setFont(font)
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Dialog)
        self.label_2.setGeometry(QtCore.QRect(60, 110, 47, 13))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.label_2.setFont(font)
        self.label_2.setObjectName("label_2")
        self.lineEdit = QtWidgets.QLineEdit(Dialog)
        self.lineEdit.setGeometry(QtCore.QRect(130, 110, 141, 20))
        self.lineEdit.setObjectName("lineEdit")
        self.whcom = QtWidgets.QComboBox(Dialog)
        self.whcom.setGeometry(QtCore.QRect(130, 70, 141, 22))
        self.whcom.setObjectName("whcom")
        list1=['Employee_ID']
        for i in list1:
            self.whcom.addItem(i)
        self.dtlbut = QtWidgets.QPushButton(Dialog)
        self.dtlbut.setGeometry(QtCore.QRect(190, 200, 75, 23))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.dtlbut.setFont(font)
        self.dtlbut.setObjectName("dtlbut")
        self.dtlbut.clicked.connect(self.delete)
        self.retranslateUi(Dialog)
        QtCore.QMetaObject.connectSlotsByName(Dialog)

    def retranslateUi(self, Dialog):
        _translate = QtCore.QCoreApplication.translate
        Dialog.setWindowTitle(_translate("Dialog", "Dialog"))
        self.label.setText(_translate("Dialog", "DELETE EMPLOYEE"))
        self.dtlbut.setText(_translate("Dialog", "DELETE"))
        
    def delete(self):
        db = MySQLdb.connect("localhost","root","test123","project")
        cursor = db.cursor()
        a=self.lineEdit.text() 
        b = self.whcom.currentText()
        sql="""delete from employee where %s='%s'"""%(b,a)
        b=self.lineEdit.text() 
        cursor.execute(sql)
        db.commit()
        db.close()
        self.lineEdit.clear()

                
class employee_update:
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(604, 298)
        self.frame = QtWidgets.QFrame(Form)
        self.frame.setGeometry(QtCore.QRect(0, 0, 591, 581))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.setcombx = QtWidgets.QComboBox(Form)
        self.setcombx.setGeometry(QtCore.QRect(40, 100, 131, 21))
        self.setcombx.setObjectName("setcombx")
        list=['Employee_Name','Mobile_Phone','Address','Income']
        for i in list:
            self.setcombx.addItem(i)
        self.wherecom = QtWidgets.QComboBox(Form)
        self.wherecom.setGeometry(QtCore.QRect(390, 100, 141, 21))
        self.wherecom.setObjectName("wherecom")
        list1=['Employee_ID']
        for i in list1:
            self.wherecom.addItem(i)
        self.setlb = QtWidgets.QLabel(Form)
        self.setlb.setGeometry(QtCore.QRect(90, 80, 31, 16))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.setlb.setFont(font)
        self.setlb.setObjectName("setlb")
        self.wherelb = QtWidgets.QLabel(Form)
        self.wherelb.setGeometry(QtCore.QRect(440, 80, 47, 13))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.wherelb.setFont(font)
        self.wherelb.setObjectName("wherelb")
        self.uplb = QtWidgets.QLabel(Form)
        self.uplb.setGeometry(QtCore.QRect(220, 10, 161, 41))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.uplb.setFont(font)
        self.uplb.setObjectName("uplb")
        self.upbut = QtWidgets.QPushButton(Form)
        self.upbut.setGeometry(QtCore.QRect(150, 240, 75, 23))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.upbut.setFont(font)
        self.upbut.setObjectName("upbut")
        self.upbut.clicked.connect(self.update)
        self.seten = QtWidgets.QLineEdit(Form)
        self.seten.setGeometry(QtCore.QRect(40, 130, 131, 20))
        self.seten.setObjectName("seten")
        self.ehereen = QtWidgets.QLineEdit(Form)
        self.ehereen.setGeometry(QtCore.QRect(390, 130, 141, 20))
        self.ehereen.setObjectName("ehereen")
        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.setlb.setText(_translate("Form", "SET"))
        self.wherelb.setText(_translate("Form", "WHERE"))
        self.uplb.setText(_translate("Form", "UPDATE"))
        self.upbut.setText(_translate("Form", "UPDATE"))
        
    
    def update(self):
        db = MySQLdb.connect("localhost","root","test123","project")
        cursor = db.cursor()
        a= self.seten.text()
        c = self.setcombx.currentText()
        b= self.ehereen.text()
        d = self.wherecom.currentText()
        sql="""update employee set %s='%s' where %s='%s'"""%(c,a,d,b)
        cursor.execute(sql)
        db.commit()
        db.close()
        self.seten.clear()
        self.ehereen.clear()
        
class show_employee:
    def __init__(self):
        self.db = MySQLdb.connect("localhost","root","test123","project")
        self.crr = self.db.cursor()
        
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(600, 590)
        self.frame = QtWidgets.QFrame(Form)
        self.frame.setGeometry(QtCore.QRect(-1, -1, 881, 41))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.frame_2 = QtWidgets.QFrame(Form)
        self.frame_2.setGeometry(QtCore.QRect(-1, 40, 41, 561))
        self.frame_2.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame_2.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_2.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_2.setObjectName("frame_2")
        self.tableWidget = QtWidgets.QTableWidget(Form)
        self.tableWidget.setGeometry(QtCore.QRect(35, 40, 841, 551))
        self.tableWidget.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.tableWidget.setObjectName("tableWidget")
        self.tableWidget.setColumnCount(5)
        self.tableWidget.setRowCount(0)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(0, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(1, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(2, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(3, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(4, item)
       
        self.crr.execute('select * from employee')
        res = self.crr.fetchall()
        self.tableWidget.setRowCount(0)
        for row_number, row_data in enumerate(res):
            self.tableWidget.insertRow(row_number)
            for column_number, data in enumerate(row_data):
                self.tableWidget.setItem(row_number,column_number,QtWidgets.QTableWidgetItem(str(data)))

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        item = self.tableWidget.horizontalHeaderItem(0)
        item.setText(_translate("Form", "Employee_ID "))
        item = self.tableWidget.horizontalHeaderItem(1)
        item.setText(_translate("Form", "Employee_Name "))
        item = self.tableWidget.horizontalHeaderItem(2)
        item.setText(_translate("Form", "Mobile_Phone "))
        item = self.tableWidget.horizontalHeaderItem(3)
        item.setText(_translate("Form", "Address"))
        item = self.tableWidget.horizontalHeaderItem(4)
        item.setText(_translate("Form", "SALARY"))

        
class Ui_Stock(object):
    def setupUi(self, Stock):
        _translate = QtCore.QCoreApplication.translate
        Stock.setWindowTitle(_translate("Stock", "Stock"))
        Stock.setObjectName("Stock")
        Stock.resize(563, 512)
        self.frame = QtWidgets.QFrame(Stock)
        self.frame.setGeometry(QtCore.QRect(0, 0, 561, 511))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(220, 120, 141, 41))
        self.pushButton.setObjectName("pushButton")
        self.pushButton_2 = QtWidgets.QPushButton(self.frame)
        self.pushButton_2.setGeometry(QtCore.QRect(220, 200, 141, 41))
        self.pushButton_2.setObjectName("pushButton_2")
        self.pushButton_3 = QtWidgets.QPushButton(self.frame)
        self.pushButton_3.setGeometry(QtCore.QRect(220, 282, 141, 41))
        self.pushButton_3.setObjectName("pushButton_3")
        self.pushButton_4 = QtWidgets.QPushButton(self.frame)
        self.pushButton_4.setGeometry(QtCore.QRect(220, 360, 141, 41))
        self.pushButton_4.setObjectName("pushButton_4")
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(210, 20, 140, 31))
        self.label.setStyleSheet("font: 75 14pt \"MS Shell Dlg 2\";")
        self.label.setObjectName("label")
        self.pushButton.setText(_translate("Stock", "ADD"))
        self.pushButton_2.setText(_translate("Stock", "UPDATE"))
        self.pushButton_3.setText(_translate("Stock", "DELETE"))
        self.pushButton_4.setText(_translate("Stock", "VIEW INVENTORY"))
        self.label.setText(_translate("Stock", "STOCK"))
        self.pushButton.clicked.connect(self.add)
        self.pushButton_2.clicked.connect(self.update)
        self.pushButton_3.clicked.connect(self.delete)
        self.pushButton_4.clicked.connect(self.show)
    def add(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=Ui_add_stock()
        self.ui.setupUi(self.window)
        self.window.show()       
    def update(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=stock_update()
        self.ui.setupUi(self.window)
        self.window.show()
    def delete(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=stock_delete()
        self.ui.setupUi(self.window)
        self.window.show()  
    def show(self):
        self.window=QtWidgets.QMainWindow()
        self.ui=show_stock()
        self.ui.setupUi(self.window)
        self.window.show()          

class Ui_add_stock(object):
    def setupUi(self, add_stock):
        add_stock.setObjectName("add_stock")
        add_stock.resize(489, 460)
        self.frame = QtWidgets.QFrame(add_stock)
        self.frame.setGeometry(QtCore.QRect(0, 0, 591, 461))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(250, 30, 91, 21))
        self.label.setStyleSheet("font: 75 12pt \"MS Shell Dlg 2\";")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(self.frame)
        self.label_2.setGeometry(QtCore.QRect(30, 100, 81, 16))
        self.label_2.setStyleSheet("font: 75 10pt \"MS Shell Dlg 2\";")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(self.frame)
        self.label_3.setGeometry(QtCore.QRect(30, 160, 101, 16))
        self.label_3.setStyleSheet("font: 75 10pt \"MS Shell Dlg 2\";")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(self.frame)
        self.label_4.setGeometry(QtCore.QRect(30, 230, 91, 16))
        self.label_4.setStyleSheet("font: 75 10pt \"MS Shell Dlg 2\";")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(self.frame)
        self.label_5.setGeometry(QtCore.QRect(30, 290, 71, 16))
        self.label_5.setStyleSheet("font: 75 10pt \"MS Shell Dlg 2\";")
        self.label_5.setObjectName("label_5")
        self.lineEdit = QtWidgets.QLineEdit(self.frame)
        self.lineEdit.setGeometry(QtCore.QRect(180, 100, 171, 20))
        self.lineEdit.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.lineEdit.setObjectName("lineEdit")
        self.lineEdit_2 = QtWidgets.QLineEdit(self.frame)
        self.lineEdit_2.setGeometry(QtCore.QRect(180, 160, 171, 20))
        self.lineEdit_2.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.lineEdit_2.setObjectName("lineEdit_2")
        self.lineEdit_3 = QtWidgets.QLineEdit(self.frame)
        self.lineEdit_3.setGeometry(QtCore.QRect(180, 230, 171, 20))
        self.lineEdit_3.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.lineEdit_3.setObjectName("lineEdit_3")
        self.lineEdit_4 = QtWidgets.QLineEdit(self.frame)
        self.lineEdit_4.setGeometry(QtCore.QRect(180, 290, 171, 20))
        self.lineEdit_4.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.lineEdit_4.setObjectName("lineEdit_4")
        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(220, 370, 81, 31))
        self.pushButton.setObjectName("pushButton")
        _translate = QtCore.QCoreApplication.translate
        add_stock.setWindowTitle(_translate("add_stock", "add_stock"))
        self.label.setText(_translate("add_stock", "ADD STOCK"))
        self.label_2.setText(_translate("add_stock", "PRODUCT ID"))
        self.label_3.setText(_translate("add_stock", "PRODUCT NAME"))
        self.label_4.setText(_translate("add_stock", "QUANTITY"))
        self.label_5.setText(_translate("add_stock", "PRICE"))
        self.pushButton.setText(_translate("add_stock", "ADD"))
        self.pushButton.clicked.connect(self.add)
  
        
    def add(self):
        db=MySQLdb.connect('localhost','root','test123','project')
        cursor=db.cursor()
        a=self.lineEdit.text()
        b=self.lineEdit_2.text()
        c=self.lineEdit_3.text()
        d=self.lineEdit_4.text()
        sql="""INSERT into stock(Product_ID,Product_Name,Quantity,Price) values ('%s','%s','%s','%s')"""%(a,b,c,d)
        cursor.execute(sql)
        db.commit()
        db.close()
        self.lineEdit.clear()
        self.lineEdit_2.clear()
        self.lineEdit_3.clear()
        self.lineEdit_4.clear()

class stock_delete:
    def setupUi(self, Dialog):
        Dialog.setObjectName("Dialog")
        Dialog.resize(400, 265)
        self.frame = QtWidgets.QFrame(Dialog)
        self.frame.setGeometry(QtCore.QRect(0, 0, 591, 581))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.label = QtWidgets.QLabel(Dialog)
        self.label.setGeometry(QtCore.QRect(100, 20, 200, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.label.setFont(font)
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Dialog)
        self.label_2.setGeometry(QtCore.QRect(60, 110, 47, 13))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.label_2.setFont(font)
        self.label_2.setObjectName("label_2")
        self.lineEdit = QtWidgets.QLineEdit(Dialog)
        self.lineEdit.setGeometry(QtCore.QRect(130, 110, 141, 20))
        self.lineEdit.setObjectName("lineEdit")
        self.whcom = QtWidgets.QComboBox(Dialog)
        self.whcom.setGeometry(QtCore.QRect(130, 70, 141, 22))
        self.whcom.setObjectName("whcom")
        list1=['Product_ID']
        for i in list1:
            self.whcom.addItem(i)
        self.dtlbut = QtWidgets.QPushButton(Dialog)
        self.dtlbut.setGeometry(QtCore.QRect(190, 200, 75, 23))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.dtlbut.setFont(font)
        self.dtlbut.setObjectName("dtlbut")
        self.dtlbut.clicked.connect(self.delete)
        self.retranslateUi(Dialog)
        QtCore.QMetaObject.connectSlotsByName(Dialog)

    def retranslateUi(self, Dialog):
        _translate = QtCore.QCoreApplication.translate
        Dialog.setWindowTitle(_translate("Dialog", "Dialog"))
        self.label.setText(_translate("Dialog", "DELETE STOCK"))
        self.dtlbut.setText(_translate("Dialog", "DELETE"))
        
    def delete(self):
        db = MySQLdb.connect("localhost","root","test123","project")
        cursor = db.cursor()
        a=self.lineEdit.text() 
        b = self.whcom.currentText()
        sql="""delete from stock where %s='%s'"""%(b,a)
        b=self.lineEdit.text() 
        cursor.execute(sql)
        db.commit()
        db.close()
        self.lineEdit.clear()

                
class stock_update:
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(604, 298)
        self.frame = QtWidgets.QFrame(Form)
        self.frame.setGeometry(QtCore.QRect(0, 0, 591, 581))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.setcombx = QtWidgets.QComboBox(Form)
        self.setcombx.setGeometry(QtCore.QRect(40, 100, 131, 21))
        self.setcombx.setObjectName("setcombx")
        list=['Product_Name','Quantity','Price']
        for i in list:
            self.setcombx.addItem(i)
        self.wherecom = QtWidgets.QComboBox(Form)
        self.wherecom.setGeometry(QtCore.QRect(390, 100, 141, 21))
        self.wherecom.setObjectName("wherecom")
        list1=['Product_ID']
        for i in list1:
            self.wherecom.addItem(i)
        self.setlb = QtWidgets.QLabel(Form)
        self.setlb.setGeometry(QtCore.QRect(90, 80, 31, 16))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.setlb.setFont(font)
        self.setlb.setObjectName("setlb")
        self.wherelb = QtWidgets.QLabel(Form)
        self.wherelb.setGeometry(QtCore.QRect(440, 80, 47, 13))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.wherelb.setFont(font)
        self.wherelb.setObjectName("wherelb")
        self.uplb = QtWidgets.QLabel(Form)
        self.uplb.setGeometry(QtCore.QRect(220, 10, 161, 41))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.uplb.setFont(font)
        self.uplb.setObjectName("uplb")
        self.upbut = QtWidgets.QPushButton(Form)
        self.upbut.setGeometry(QtCore.QRect(150, 240, 75, 23))
        font = QtGui.QFont()
        font.setPointSize(10)
        self.upbut.setFont(font)
        self.upbut.setObjectName("upbut")
        self.upbut.clicked.connect(self.update)
        self.seten = QtWidgets.QLineEdit(Form)
        self.seten.setGeometry(QtCore.QRect(40, 130, 131, 20))
        self.seten.setObjectName("seten")
        self.ehereen = QtWidgets.QLineEdit(Form)
        self.ehereen.setGeometry(QtCore.QRect(390, 130, 141, 20))
        self.ehereen.setObjectName("ehereen")
        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.setlb.setText(_translate("Form", "SET"))
        self.wherelb.setText(_translate("Form", "WHERE"))
        self.uplb.setText(_translate("Form", "UPDATE STOCK"))
        self.upbut.setText(_translate("Form", "UPDATE"))
        
    
    def update(self):
        db = MySQLdb.connect("localhost","root","test123","project")
        cursor = db.cursor()
        a= self.seten.text()
        c = self.setcombx.currentText()
        b= self.ehereen.text()
        d = self.wherecom.currentText()
        sql="""update stock set %s='%s' where %s='%s'"""%(c,a,d,b)
        cursor.execute(sql)
        db.commit()
        db.close()
        self.seten.clear()
        self.ehereen.clear()
        
class show_stock:
    def __init__(self):
        self.db = MySQLdb.connect("localhost","root","test123","project")
        self.crr = self.db.cursor()
        
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(500, 590)
        self.frame = QtWidgets.QFrame(Form)
        self.frame.setGeometry(QtCore.QRect(-1, -1, 881, 41))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.frame_2 = QtWidgets.QFrame(Form)
        self.frame_2.setGeometry(QtCore.QRect(-1, 40, 41, 561))
        self.frame_2.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame_2.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_2.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_2.setObjectName("frame_2")
        self.tableWidget = QtWidgets.QTableWidget(Form)
        self.tableWidget.setGeometry(QtCore.QRect(35, 40, 841, 551))
        self.tableWidget.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.tableWidget.setObjectName("tableWidget")
        self.tableWidget.setColumnCount(4)
        self.tableWidget.setRowCount(0)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(0, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(1, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(2, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(3, item)

       
        self.crr.execute('select * from stock')
        res = self.crr.fetchall()
        self.tableWidget.setRowCount(0)
        for row_number, row_data in enumerate(res):
            self.tableWidget.insertRow(row_number)
            for column_number, data in enumerate(row_data):
                self.tableWidget.setItem(row_number,column_number,QtWidgets.QTableWidgetItem(str(data)))

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        item = self.tableWidget.horizontalHeaderItem(0)
        item.setText(_translate("Form", "Product_ID "))
        item = self.tableWidget.horizontalHeaderItem(1)
        item.setText(_translate("Form", "Product_Name "))
        item = self.tableWidget.horizontalHeaderItem(2)
        item.setText(_translate("Form", "Quantity "))
        item = self.tableWidget.horizontalHeaderItem(3)
        item.setText(_translate("Form", "Price"))

class Ui_order(object):
    def setupUi(self, order):
        _translate = QtCore.QCoreApplication.translate
        order.setObjectName("order")
        order.resize(482, 411)
        self.frame = QtWidgets.QFrame(order)
        self.frame.setGeometry(QtCore.QRect(0, 0, 491, 421))
        self.frame.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(126, 126, 126, 255), stop:1 rgba(255, 255, 255, 255));background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 191, 237, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(220, 20, 61, 21))
        self.label.setStyleSheet("font: 75 12pt \"MS Shell Dlg 2\";")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(self.frame)
        self.label_2.setGeometry(QtCore.QRect(40, 90, 81, 16))
        self.label_2.setStyleSheet("font: 75 10pt \"MS Shell Dlg 2\";")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(self.frame)
        self.label_3.setGeometry(QtCore.QRect(40, 143, 101, 20))
        self.label_3.setStyleSheet("font: 75 10pt \"MS Shell Dlg 2\";")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(self.frame)
        self.label_4.setGeometry(QtCore.QRect(40, 190, 71, 16))
        self.label_4.setStyleSheet("font: 75 10pt \"MS Shell Dlg 2\";")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(self.frame)
        self.label_5.setGeometry(QtCore.QRect(40, 240, 41, 16))
        self.label_5.setStyleSheet("font: 75 10pt \"MS Shell Dlg 2\";")
        self.label_5.setObjectName("label_5")
        self.lineEdit = QtWidgets.QLineEdit(self.frame)
        self.lineEdit.setGeometry(QtCore.QRect(170, 90, 161, 20))
        self.lineEdit.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.lineEdit.setObjectName("lineEdit")
        self.lineEdit_2 = QtWidgets.QLineEdit(self.frame)
        self.lineEdit_2.setGeometry(QtCore.QRect(170, 140, 161, 20))
        self.lineEdit_2.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.lineEdit_2.setObjectName("lineEdit_2")
        self.lineEdit_3 = QtWidgets.QLineEdit(self.frame)
        self.lineEdit_3.setGeometry(QtCore.QRect(170, 190, 161, 20))
        self.lineEdit_3.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.lineEdit_3.setObjectName("lineEdit_3")
        self.lineEdit_4 = QtWidgets.QLineEdit(self.frame)
        self.lineEdit_4.setGeometry(QtCore.QRect(170, 240, 161, 20))
        self.lineEdit_4.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.lineEdit_4.setObjectName("lineEdit_4")
        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(180, 310, 75, 23))
        self.pushButton.setObjectName("pushButton")
        order.setWindowTitle(_translate("order", "order"))
        self.label.setText(_translate("order", "ORDER"))
        self.label_2.setText(_translate("order", "PRODUCT_ID"))
        self.label_3.setText(_translate("order", "PRODUCT_NAME"))
        self.label_4.setText(_translate("order", "QUANTITY"))
        self.label_5.setText(_translate("order", "PRICE"))
        self.pushButton.setText(_translate("order", "CONFIRM"))


        





        

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-5a6f08ba1e95> in <module>
#       2 from PyQt5 import QtCore, QtGui, QtWidgets
#       3 from tkinter import *
# ----> 4 import MySQLdb
#       5
#       6 class Ui_Form(object):
#
# ModuleNotFoundError: No module named 'MySQLdb'
